# %%
# Scraping Data from a Real Website + Pandas

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/List_of_unicorn_startup_companies'
page = requests.get(url)
soup = BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of unicorn startup companies - Wikipedia</title>
# ...

# %%
soup.find_all('table')[1]
# Out:
# <table class="wikitable">
# <caption>Table of the number of unicorn startups by country as of October 7, 2022
# </caption>
# <tbody><tr>
# <th>Country</th>
# <th>Number of unicorns
# </th></tr>
# <tr>
# <td>US</td>
# <td>645
# </td></tr>
# <tr>
# <td>China</td>
# <td>302<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup>
# </td></tr>
# <tr>
# <td>India</td>
# <td>113<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
# </td></tr>
# <tr>
# <td>UK</td>
# <td>46
# </td></tr>
# <tr>
# <td>France</td>
# <td>34<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
# </td></tr>
# <tr>
# <td>Germany</td>
# <td>29
# </td></tr>
# <tr>
# <td>Israel</td>
# <td>22
# </td></tr>
# <tr>
# <td>Canada</td>
# <td>19
# </td></tr>
# <tr>
# <td>Brazil</td>
# <td>16
# </td></tr>
# <tr>
# <td>South Korea</td>
# <td>16
# </td></tr>
# <tr>
# <td>Singapore</td>
# <td>13
# </td></tr>
# <tr>
# <td>Japan</td>
# <td>12
# </td></tr>
# ...

# %%
soup.find('table', class_ ="wikitable")
# Out:
# <table class="wikitable">
# <caption>Historical progress of unicorns
# </caption>
# <tbody><tr>
# <th># Unicorns
# </th>
# <th>Total valuation<br/>(US$ billions)
# </th>
# <th>Date
# </th>
# <th>Reported by
# </th></tr>
# <tr>
# <td>39
# </td>
# <td>
# </td>
# <td>Late October/Early November 2013
# </td>
# <td><i>TechCrunch</i><sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
# </td></tr>
# <tr>
# <td>82
# </td>
# <td>
# </td>
# <td>Late January 2015
# </td>
# <td><i><a href="/wiki/Forbes" title="Forbes">Forbes</a></i>, CB Insights<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </td></tr>
# <tr>
# <td>229
# </td>
# <td>1,300
# </td>
# <td>January 2016
# </td>
# <td><i><a href="/wiki/VentureBeat" title="VentureBeat">VentureBeat</a></i><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </td></tr>
# <tr>
# <td>208
# </td>
# <td>761
# </td>
# <td>December 2016
# </td>
# ...

# %%
table =soup.find_all('table')[1]

# %%
print (table)
# Out:
# <table class="wikitable">
# <caption>Table of the number of unicorn startups by country as of October 7, 2022
# </caption>
# <tbody><tr>
# <th>Country</th>
# <th>Number of unicorns
# </th></tr>
# <tr>
# <td>US</td>
# <td>645
# </td></tr>
# <tr>
# <td>China</td>
# <td>302<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup>
# </td></tr>
# <tr>
# <td>India</td>
# <td>113<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup>
# </td></tr>
# <tr>
# <td>UK</td>
# <td>46
# </td></tr>
# <tr>
# <td>France</td>
# <td>34<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
# </td></tr>
# <tr>
# <td>Germany</td>
# <td>29
# </td></tr>
# <tr>
# <td>Israel</td>
# <td>22
# </td></tr>
# <tr>
# <td>Canada</td>
# <td>19
# </td></tr>
# <tr>
# <td>Brazil</td>
# <td>16
# </td></tr>
# <tr>
# <td>South Korea</td>
# <td>16
# </td></tr>
# <tr>
# <td>Singapore</td>
# <td>13
# </td></tr>
# <tr>
# <td>Japan</td>
# <td>12
# </td></tr>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th>Country</th>,
#  <th>Number of unicorns
#  </th>]

# %%
world_table_titles = [titles.text.strip() for titles in world_titles]

# %%
print (world_table_titles)
# Out:
# ['Country', 'Number of unicorns']

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Country, Number of unicorns]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#         Country Number of unicorns
# 0            US                645
# 1         China            302[15]
# 2         India            113[16]
# 3            UK                 46
# 4        France             34[17]
# 5       Germany                 29
# 6        Israel                 22
# 7        Canada                 19
# 8        Brazil                 16
# 9   South Korea                 16
# 10    Singapore                 13
# 11        Japan                 12
# 12    Indonesia                  8
# 13    Australia                  8
# 14       Mexico                  8
# 15       Poland                  8
# 16       Sweden                  8
# 17    Hong Kong                  7
# 18  Netherlands                  7
# 19      Ireland                  6
# 20  Switzerland                  6
# 21          UAE                  6
# 22       Norway                  5
# 23        Spain                  4
# 24      Vietnam                  4
# 25       Russia                  3
# ...

# %%
df.to_csv(r'C:\Users\Archana\OneDrive\Desktop\jupyter\Startup.csv', index = False)
